# %% [markdown]
# <a href="https://colab.research.google.com/github/onepixelm/hazi03/blob/master/dixyconv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


#lp = np.linspace(1,1000,1000)

# %%
print(lp.shape,type(lp))
# Out:
# (1000,) <class 'numpy.ndarray'>

# %%
from google.colab import files

uploaded = files.upload()
file  = open("BP_d.txt", 'r')  
head = file.readlines()[1:] 
file.close()
# Out:
#      <input type="file" id="files-c229c6db-174c-4566-81cf-958afc5457a9" name="files[]" multiple disabled />
#      <output id="result-c229c6db-174c-4566-81cf-958afc5457a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BP_d.txt to BP_d.txt

# %%
head2 = [ float(s.split(';')[1]) for s in head ]
print(len(head2))

min_temp = head2[0]
max_temp = head2[0]
for t in head2:
  if t < min_temp:
    min_temp = t
  if t > max_temp:
    max_temp = t
print("Min temp: {} Max temp: {}".format(min_temp,max_temp))
x = (np.asarray([head2[-40000:]]) - min_temp)/(max_temp - min_temp)
 #x = x.T
# Out:
# 40177
# Min temp: -20.6 Max temp: 33.1

# %%
print(x.shape,type(x))
x.shape = (40000,) 
 #x.reshape(1000)
print(x.shape,type(x))
# Out:
# (1, 40000) <class 'numpy.ndarray'>
# (40000,) <class 'numpy.ndarray'>

# %%
plt.figure(figsize=(10,10))
plt.plot(x)

# %%
window_size=20

valid_split=0.3
test_split =0.2

from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.optimizers import SGD
from keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn import preprocessing
from keras.layers.convolutional import Convolution1D, MaxPooling1D
from keras.layers.convolutional import Conv1D

def make_1d_convnet(window_size, filter_length, nb_input_series=1, nb_output=1, nb_filter=4):
  model = Sequential()
  # Conv1D(filters=nb_filter, kernel_size=filter_length, activation='relu',...)
  model.add(Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu', 
                           input_shape=(window_size, nb_input_series, )))
  model.add(MaxPooling1D()) # filter:2, stride:2
  model.add(Convolution1D(nb_filter=nb_filter, filter_length=filter_length, activation='relu'))
  model.add(MaxPooling1D()) # filter:2, stride:2
  model.add(Flatten())  
  model.add(Dense(1,activation='linear'))
  model.compile(loss='mse', optimizer='adam', metrics=['mae'])
  
  return model

#model=make_1d_convnet(window_size=window_size, filter_length=5)
# Out:
# Using TensorFlow backend.

# %%
def make_timeseries_innstance(timeseries, window_size):
  timeseries = np.asarray(timeseries)
  assert 0 < window_size < timeseries.shape[0], "Out of range"
  
  X = np.atleast_3d(np.array([timeseries[start:start+window_size] for start in range(0,timeseries.shape[0]-window_size)]))
  
  assert len(X.shape) == 3, "Dimension error"
  Y = timeseries[window_size:]
  
  return X, Y

# %%
def eval_timeseries(timeseries, window_length):
  filter_length = 5
  nb_filter = 4
  timeseries = np.atleast_2d(timeseries)
  if timeseries.shape[0]==1:
    timeseries = timeseries.T
  nb_samples, nb_series = timeseries.shape
  
  model=make_1d_convnet(window_size=window_size, 
                        filter_length=filter_length, 
                        nb_input_series=nb_series,
                        nb_filter=nb_filter)
  
  print(model.summary())
  X, Y = make_timeseries_innstance(timeseries, window_size)
  
  test_size = int(nb_samples*(1-test_split))
  valid_size = int(nb_samples*(1-valid_split-test_split))
  
  X_train, Y_train = X[:valid_size], Y[:valid_size]
  X_valid, Y_valid = X[valid_size:test_size], Y[valid_size:test_size]
  X_test, Y_test   = X[test_size:], Y[test_size:]
  
  ##$$$$$ NE FELEJTSETEK EL A STANDARADIZALAST $$$$$$
  ##$$$$$$ NE FELEJTESTEK EL EARLY STOPPINGOT ES MCP-t $$$$
  
  model.fit(X_train, Y_train, epochs=50, validation_data=[X_valid,Y_valid], verbose=2)
  
  ##$$$$$ NE FELETSETEK EL AZ MCP-t VISSZATOLTENI $$$$
  
  preds = model.predict(X_test)
  
  plt.figure(figsize=(10,20))
  plt.plot(preds, color='r')
  plt.plot(Y_test, color='b')

# %%
eval_timeseries(x, window_size)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", input_shape=(20, 1), filters=4, kernel_size=5)`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: UserWarning: Update your `Conv1D` call to the Keras 2 API: `Conv1D(activation="relu", filters=4, kernel_size=5)`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_1 (Conv1D)            (None, 16, 4)             24
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 8, 4)              0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 4, 4)              84
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 2, 4)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 117
# Trainable params: 117
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 19999 samples, validate on 12001 samples
# Epoch 1/50
#  - 2s - loss: 0.0063 - mean_absolute_error: 0.0626 - val_loss: 0.0052 - val_mean_absolute_error: 0.0579
# Epoch 2/50
#  - 1s - loss: 0.0047 - mean_absolute_error: 0.0551 - val_loss: 0.0043 - val_mean_absolute_error: 0.0523
# Epoch 3/50
#  - 1s - loss: 0.0040 - mean_absolute_error: 0.0507 - val_loss: 0.0039 - val_mean_absolute_error: 0.0495
# Epoch 4/50
#  - 1s - loss: 0.0037 - mean_absolute_error: 0.0487 - val_loss: 0.0036 - val_mean_absolute_error: 0.0481
# Epoch 5/50
#  - 1s - loss: 0.0036 - mean_absolute_error: 0.0477 - val_loss: 0.0036 - val_mean_absolute_error: 0.0484
# Epoch 6/50
#  - 1s - loss: 0.0035 - mean_absolute_error: 0.0470 - val_loss: 0.0034 - val_mean_absolute_error: 0.0463
# Epoch 7/50
#  - 1s - loss: 0.0034 - mean_absolute_error: 0.0466 - val_loss: 0.0033 - val_mean_absolute_error: 0.0460
# Epoch 8/50
#  - 1s - loss: 0.0034 - mean_absolute_error: 0.0461 - val_loss: 0.0033 - val_mean_absolute_error: 0.0454
# Epoch 9/50
#  - 1s - loss: 0.0033 - mean_absolute_error: 0.0456 - val_loss: 0.0032 - val_mean_absolute_error: 0.0445
# Epoch 10/50
#  - 1s - loss: 0.0032 - mean_absolute_error: 0.0453 - val_loss: 0.0033 - val_mean_absolute_error: 0.0461
# Epoch 11/50
#  - 1s - loss: 0.0032 - mean_absolute_error: 0.0449 - val_loss: 0.0032 - val_mean_absolute_error: 0.0454
# Epoch 12/50
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0445 - val_loss: 0.0030 - val_mean_absolute_error: 0.0434
# Epoch 13/50
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0441 - val_loss: 0.0031 - val_mean_absolute_error: 0.0432
# Epoch 14/50
#  - 1s - loss: 0.0031 - mean_absolute_error: 0.0440 - val_loss: 0.0029 - val_mean_absolute_error: 0.0432
# Epoch 15/50
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0435 - val_loss: 0.0030 - val_mean_absolute_error: 0.0439
# Epoch 16/50
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0434 - val_loss: 0.0030 - val_mean_absolute_error: 0.0425
# Epoch 17/50
#  - 1s - loss: 0.0030 - mean_absolute_error: 0.0431 - val_loss: 0.0028 - val_mean_absolute_error: 0.0425
# Epoch 18/50
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0428 - val_loss: 0.0028 - val_mean_absolute_error: 0.0424
# Epoch 19/50
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0427 - val_loss: 0.0028 - val_mean_absolute_error: 0.0429
# Epoch 20/50
#  - 1s - loss: 0.0029 - mean_absolute_error: 0.0424 - val_loss: 0.0028 - val_mean_absolute_error: 0.0427
# Epoch 21/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0422 - val_loss: 0.0027 - val_mean_absolute_error: 0.0409
# Epoch 22/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0419 - val_loss: 0.0027 - val_mean_absolute_error: 0.0412
# Epoch 23/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0419 - val_loss: 0.0027 - val_mean_absolute_error: 0.0418
# Epoch 24/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0416 - val_loss: 0.0028 - val_mean_absolute_error: 0.0421
# Epoch 25/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0416 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 26/50
#  - 1s - loss: 0.0028 - mean_absolute_error: 0.0414 - val_loss: 0.0026 - val_mean_absolute_error: 0.0402
# Epoch 27/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0412 - val_loss: 0.0026 - val_mean_absolute_error: 0.0399
# Epoch 28/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0411 - val_loss: 0.0027 - val_mean_absolute_error: 0.0422
# Epoch 29/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0412 - val_loss: 0.0027 - val_mean_absolute_error: 0.0404
# Epoch 30/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0410 - val_loss: 0.0025 - val_mean_absolute_error: 0.0396
# Epoch 31/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0409 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 32/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0410 - val_loss: 0.0025 - val_mean_absolute_error: 0.0399
# Epoch 33/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0408 - val_loss: 0.0027 - val_mean_absolute_error: 0.0403
# Epoch 34/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0408 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 35/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0406 - val_loss: 0.0025 - val_mean_absolute_error: 0.0394
# Epoch 36/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0405 - val_loss: 0.0025 - val_mean_absolute_error: 0.0395
# Epoch 37/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0408 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 38/50
#  - 1s - loss: 0.0027 - mean_absolute_error: 0.0406 - val_loss: 0.0025 - val_mean_absolute_error: 0.0391
# Epoch 39/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0026 - val_mean_absolute_error: 0.0403
# Epoch 40/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0025 - val_mean_absolute_error: 0.0389
# Epoch 41/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.0025 - val_mean_absolute_error: 0.0388
# Epoch 42/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 43/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0401 - val_loss: 0.0025 - val_mean_absolute_error: 0.0402
# Epoch 44/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.0024 - val_mean_absolute_error: 0.0390
# Epoch 45/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0400 - val_loss: 0.0026 - val_mean_absolute_error: 0.0391
# Epoch 46/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0401 - val_loss: 0.0027 - val_mean_absolute_error: 0.0426
# Epoch 47/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0402 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 48/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0401 - val_loss: 0.0024 - val_mean_absolute_error: 0.0388
# Epoch 49/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0400 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384
# Epoch 50/50
#  - 1s - loss: 0.0026 - mean_absolute_error: 0.0400 - val_loss: 0.0024 - val_mean_absolute_error: 0.0384

# %%
 plt.figure(figsize=(10,20))
 plt.plot(preds, color='r')
 plt.plot(Y_test, color='b')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3d4b26017722> in <module>()
#       1 plt.figure(figsize=(10,20))
# ----> 2 plt.plot(preds, color='r')
#       3 plt.plot(Y_test, color='b')
#
# NameError: name 'preds' is not defined
